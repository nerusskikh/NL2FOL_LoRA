# %%
import json
import os

from unsloth import FastLanguageModel
from tqdm.auto import tqdm

from eval_utils import evaluate_generation
from utils import split_sample

# %%
MODEL_FP = 'DPO_qlora/'
OUT_FOLDER = 'DPO_qlora_test_samples'
N_FOLDS = 8

# %%
os.makedirs(OUT_FOLDER)

# %%
model, tokenizer = FastLanguageModel.from_pretrained(MODEL_FP)
# Out:
# ==((====))==  Unsloth: Fast Llama patching release 2024.4
#    \\   /|    GPU: NVIDIA RTX 6000 Ada Generation. Max memory: 47.507 GB. Platform = Linux.
# O^O/ \_/ \    Pytorch: 2.2.1. CUDA = 8.9. CUDA Toolkit = 12.1.
# \        /    Bfloat16 = TRUE. Xformers = 0.0.25. FA = False.
#  "-____-"     Free Apache license: http://github.com/unslothai/unsloth
# Loading checkpoint shards:   0%|          | 0/6 [00:00<?, ?it/s]
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# Unsloth cannot patch MLP layers with our manual autograd engine since either LoRA adapters
# are not enabled or a bias term (like in Qwen) is used.
# Unsloth cannot patch Attention layers with our manual autograd engine since either LoRA adapters
# are not enabled or a bias term (like in Qwen) is used.
# ...

# %%
with open('/root/linc/folio_filtered_test_llama3-instruct.json', 'r') as f:
    test_data = json.load(f)

# %%
for attempt in range(N_FOLDS):
    for sample in tqdm(test_data):
        test_text, __  = split_sample(sample['text'])
        
        inputs = tokenizer([test_text], return_tensors="pt")
        result = model.generate(**inputs, max_new_tokens = 512, temperature=1.05, top_p=0.9, do_sample=True)
        output_text = tokenizer.decode(result[0])
        output_text_pred = output_text.split(sep)[-1]
        
        predicted_label = evaluate_generation(output_text_pred)
    
        with open(os.path.join(OUT_FOLDER, f"""example_id_{sample["example_id"]}_attempt_{attempt}_gt_{sample["label"]}_pred_{predicted_label}.txt"""), 'w') as f:
                f.write(output_text)
# Out:
#   0%|          | 0/203 [00:00<?, ?it/s]
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# ...
